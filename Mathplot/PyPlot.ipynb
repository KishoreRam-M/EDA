# %% [raw]
# !

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,9]
y=[2,4,9,16,25,26,49,64,81]
## plot cutomize


plt.plot(x, y, color="gold", linestyle="--", marker="o",linewidth=10)
plt.xlabel('Xxx')
plt.ylabel('Yyy')
plt.title("Summa ")
plt.show()
